# %%
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/databricks-datasets/samples/docs/README.md")
# Transformation: Filter data
filtered_df = df

# Action: Count the filtered rows
print(filtered_df.count())

# Action: Display the filtered data
display(filtered_df.limit(5))

# Write the transformed data to a Delta Lake table
#filtered_df.write.format("delta").mode("overwrite").saveAsTable("my_filtered_data")
